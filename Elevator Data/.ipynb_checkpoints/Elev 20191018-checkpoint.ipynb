# %%
import pandas as pd
import numpy as np
import pymysql
import matplotlib.pyplot as plt
import datetime

# %%
conn = pymysql.connect(
    host='192.168.100.120',
    port=16033,
    user='root',
    password='its@1234',
    db='UYeG_Cloud',
    charset='utf8'
)

curs = conn.cursor()

set_day1 = '2019-10-18 13:56:30'
set_day2 = '2019-10-18 13:58:00'



sql = "SELECT DataSavedTime, Item005 FROM HisItemCurrHalf \
    WHERE DataSavedTime \
    BETWEEN '"+set_day1+"' and '"+set_day2+"' ORDER BY DataSavedTime ASC"
print(sql)
curs.execute(sql)
rows=curs.fetchall()


data = list(rows)
df = pd.DataFrame(data)

df.columns = ['DataSavedTime', 'Item005']

print(df)
print(len(df))
conn.close()

plt.figure(figsize=(15,5))
plt.plot(df['DataSavedTime'], df['Item005'], label="Value")
plt.legend(loc='best')
plt.title("Current 0.05")
plt.grid()
plt.show()
# Out:
# SELECT DataSavedTime, Item005 FROM HisItemCurrHalf     WHERE DataSavedTime     BETWEEN '2019-10-18 13:56:30' and '2019-10-18 13:58:00' ORDER BY DataSavedTime ASC
#                DataSavedTime  Item005
# 0    2019-10-18 13:56:30.000      NaN
# 1    2019-10-18 13:56:30.050      NaN
# 2    2019-10-18 13:56:30.100      NaN
# 3    2019-10-18 13:56:30.150      NaN
# 4    2019-10-18 13:56:30.200      NaN
# ...                      ...      ...
# 1796 2019-10-18 13:57:59.800      NaN
# 1797 2019-10-18 13:57:59.850      NaN
# 1798 2019-10-18 13:57:59.900      NaN
# 1799 2019-10-18 13:57:59.950      NaN
# 1800 2019-10-18 13:58:00.000      NaN
#
# [1801 rows x 2 columns]
# 1801
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
conn2 = pymysql.connect(
    host='192.168.100.120',
    port=16033,
    user='root',
    password='its@1234',
    db='UYeG_Cloud',
    charset='utf8'
)
curs = conn2.cursor()

set_day1 = '2019-10-18 13:56:30'
set_day2 = '2019-10-18 13:58:00'


sql = "SELECT DataSavedTime, Item005 FROM HisItemCurr \
    WHERE DataSavedTime \
    BETWEEN '"+set_day1+"' and '"+set_day2+"' ORDER BY DataSavedTime ASC"
print(sql)
curs.execute(sql)
rows=curs.fetchall()


data = list(rows)
df = pd.DataFrame(data)

df.columns = ['DataSavedTime', 'Item005']

print(df)
print(len(df))
conn2.close()

plt.figure(figsize=(15,5))
plt.plot(df['DataSavedTime'], df['Item005'], label="Value")
plt.legend(loc='best')
plt.title("Current 0.1")
plt.grid()
plt.show()
# Out:
# SELECT DataSavedTime, Item005 FROM HisItemCurr     WHERE DataSavedTime     BETWEEN '2019-10-18 13:56:30' and '2019-10-18 13:58:00' ORDER BY DataSavedTime ASC
#               DataSavedTime  Item005
# 0   2019-10-18 13:56:30.000      NaN
# 1   2019-10-18 13:56:30.100      NaN
# 2   2019-10-18 13:56:30.200      NaN
# 3   2019-10-18 13:56:30.300      NaN
# 4   2019-10-18 13:56:30.400      NaN
# ..                      ...      ...
# 896 2019-10-18 13:57:59.600      NaN
# 897 2019-10-18 13:57:59.700      NaN
# 898 2019-10-18 13:57:59.800      NaN
# 899 2019-10-18 13:57:59.900      NaN
# 900 2019-10-18 13:58:00.000      NaN
#
# [901 rows x 2 columns]
# 901

# %%
conn3 = pymysql.connect(
    host='192.168.100.120',
    port=16033,
    user='root',
    password='its@1234',
    db='UYeG_Cloud',
    charset='utf8'
)
curs = conn3.cursor()

set_day1 = '2019-10-18 13:56:30'
set_day2 = '2019-10-18 13:58:00'


sql = "SELECT DataSavedTime, Item005 FROM HisItemCurrSecond \
    WHERE DataSavedTime \
    BETWEEN '"+set_day1+"' and '"+set_day2+"' ORDER BY DataSavedTime ASC"
print(sql)
curs.execute(sql)
rows=curs.fetchall()


data = list(rows)
df = pd.DataFrame(data)

df.columns = ['DataSavedTime', 'Item005']

print(df)
print(len(df))
conn3.close()

plt.figure(figsize=(15,5))
plt.plot(df['DataSavedTime'], df['Item005'], label="Value")
plt.legend(loc='best')
plt.title("Current 1sec")
plt.grid()
plt.show()
# Out:
# SELECT DataSavedTime, Item005 FROM HisItemCurrSecond     WHERE DataSavedTime     BETWEEN '2019-10-18 13:56:30' and '2019-10-18 13:58:00' ORDER BY DataSavedTime ASC
#          DataSavedTime  Item005
# 0  2019-10-18 13:56:30      NaN
# 1  2019-10-18 13:56:31      NaN
# 2  2019-10-18 13:56:32      NaN
# 3  2019-10-18 13:56:33      NaN
# 4  2019-10-18 13:56:34      NaN
# ..                 ...      ...
# 86 2019-10-18 13:57:56    32.02
# 87 2019-10-18 13:57:57    14.27
# 88 2019-10-18 13:57:58     1.42
# 89 2019-10-18 13:57:59      NaN
# 90 2019-10-18 13:58:00      NaN
#
# [91 rows x 2 columns]
# 91

# %%
conn3 = pymysql.connect(
    host='192.168.100.50',
    port=16033,
    user='root',
    password='its@1234',
    db='UYeG_Cloud',
    charset='utf8'
)
curs = conn3.cursor()

set_day1 = '2019-10-18 13:56:30'
set_day2 = '2019-10-18 13:58:00'


sql = "SELECT DataSavedTime, Item005 FROM HisItemCurrSecond \
    WHERE DataSavedTime \
    BETWEEN '"+set_day1+"' and '"+set_day2+"' ORDER BY DataSavedTime ASC"
print(sql)
curs.execute(sql)
rows=curs.fetchall()


data = list(rows)
df = pd.DataFrame(data)

df.columns = ['DataSavedTime', 'Item005']

print(df)
print(len(df))
conn3.close()

plt.figure(figsize=(15,5))
plt.plot(df['DataSavedTime'], df['Item005'], label="Value")
plt.legend(loc='best')
plt.title("Current 1sec")
plt.grid()
plt.show()
# Out:
# SELECT DataSavedTime, Item005 FROM HisItemCurrSecond     WHERE DataSavedTime     BETWEEN '2019-10-18 13:56:30' and '2019-10-18 13:58:00' ORDER BY DataSavedTime ASC
#          DataSavedTime  Item005
# 0  2019-10-18 13:56:30      NaN
# 1  2019-10-18 13:56:31      NaN
# 2  2019-10-18 13:56:32      NaN
# 3  2019-10-18 13:56:33      NaN
# 4  2019-10-18 13:56:34      NaN
# ..                 ...      ...
# 86 2019-10-18 13:57:56    29.17
# 87 2019-10-18 13:57:57     3.69
# 88 2019-10-18 13:57:58     3.69
# 89 2019-10-18 13:57:59      NaN
# 90 2019-10-18 13:58:00      NaN
#
# [91 rows x 2 columns]
# 91

# %%
conn = pymysql.connect(
    host='192.168.100.120',
    port=16033,
    user='root',
    password='its@1234',
    db='UYeG_Cloud',
    charset='utf8'
)

curs = conn.cursor()

set_day1 = '2019-10-28 08:25:30'
set_day2 = '2019-10-28 08:30:30'



sql = "SELECT DataSavedTime, Item005 FROM HisItemActivePower \
    WHERE DataSavedTime \
    BETWEEN '"+set_day1+"' and '"+set_day2+"' ORDER BY DataSavedTime ASC"
print(sql)
curs.execute(sql)
rows=curs.fetchall()


data = list(rows)
df = pd.DataFrame(data)

df.columns = ['DataSavedTime', 'Item005']

print(df)
print(len(df))
conn.close()

plt.figure(figsize=(15,5))
plt.plot(df['DataSavedTime'], df['Item005'], label="Value")
plt.legend(loc='best')
plt.title("ACTIVE POWER 0.1")
plt.grid()
plt.show()
# Out:
# SELECT DataSavedTime, Item005 FROM HisItemActivePower     WHERE DataSavedTime     BETWEEN '2019-10-28 08:25:30' and '2019-10-28 08:30:30' ORDER BY DataSavedTime ASC
#                DataSavedTime  Item005
# 0    2019-10-28 08:25:30.000      NaN
# 1    2019-10-28 08:25:30.100      NaN
# 2    2019-10-28 08:25:30.200      NaN
# 3    2019-10-28 08:25:30.300      NaN
# 4    2019-10-28 08:25:30.400      NaN
# ...                      ...      ...
# 2996 2019-10-28 08:30:29.600      NaN
# 2997 2019-10-28 08:30:29.700      NaN
# 2998 2019-10-28 08:30:29.800      NaN
# 2999 2019-10-28 08:30:29.900      NaN
# 3000 2019-10-28 08:30:30.000      NaN
#
# [3001 rows x 2 columns]
# 3001

# %%
conn = pymysql.connect(
    host='192.168.100.120',
    port=16033,
    user='root',
    password='its@1234',
    db='UYeG_Cloud',
    charset='utf8'
)

curs = conn.cursor()

set_day1 = '2019-10-09 18:58:30'
set_day2 = '2019-10-09 18:59:30'



sql = "SELECT DataSavedTime, Item039 FROM HisItemCurr \
    WHERE DataSavedTime \
    BETWEEN '"+set_day1+"' and '"+set_day2+"' ORDER BY DataSavedTime ASC"
print(sql)
curs.execute(sql)
rows=curs.fetchall()


data = list(rows)
df = pd.DataFrame(data)

df.columns = ['DataSavedTime', 'Item039']

print(df)
print(len(df))
conn.close()

plt.figure(figsize=(15,5))
plt.plot(df['DataSavedTime'], df['Item039'], label="Value")
plt.legend(loc='best')
plt.title("CURRENT 0.1")
plt.grid()
plt.show()
# Out:
# SELECT DataSavedTime, Item039 FROM HisItemCurr     WHERE DataSavedTime     BETWEEN '2019-10-09 18:58:30' and '2019-10-09 18:59:30' ORDER BY DataSavedTime ASC
#               DataSavedTime  Item039
# 0   2019-10-09 18:58:30.000     9.61
# 1   2019-10-09 18:58:30.100     9.61
# 2   2019-10-09 18:58:30.200     9.61
# 3   2019-10-09 18:58:30.300     9.61
# 4   2019-10-09 18:58:30.400     1.76
# ..                      ...      ...
# 596 2019-10-09 18:59:29.600     0.74
# 597 2019-10-09 18:59:29.700     0.74
# 598 2019-10-09 18:59:29.800     0.74
# 599 2019-10-09 18:59:29.900     0.74
# 600 2019-10-09 18:59:30.000     0.74
#
# [601 rows x 2 columns]
# 601

# %%
conn2 = pymysql.connect(
    host='192.168.100.120',
    port=16033,
    user='root',
    password='its@1234',
    db='UYeG_Cloud',
    charset='utf8'
)
curs = conn2.cursor()

set_day1 = '2019-11-20 08:37:20'
set_day2 = '2019-11-20 08:39:30'


sql = "SELECT DataSavedTime, Item005 FROM HisItemCurrHalf \
    WHERE DataSavedTime \
    BETWEEN '"+set_day1+"' and '"+set_day2+"' ORDER BY DataSavedTime ASC"
print(sql)
curs.execute(sql)
rows=curs.fetchall()


data = list(rows)
df = pd.DataFrame(data)

df.columns = ['DataSavedTime', 'Item005']

print(df)
print(len(df))
conn2.close()

plt.figure(figsize=(15,5))
plt.plot(df['DataSavedTime'], df['Item005'], label="Value")
plt.legend(loc='best')
plt.title("Current 0.05")
plt.grid()
plt.show()
# Out:
# SELECT DataSavedTime, Item005 FROM HisItemCurrHalf     WHERE DataSavedTime     BETWEEN '2019-11-20 08:37:20' and '2019-11-20 08:39:30' ORDER BY DataSavedTime ASC
#                DataSavedTime  Item005
# 0    2019-11-20 08:37:20.000      NaN
# 1    2019-11-20 08:37:20.050      NaN
# 2    2019-11-20 08:37:20.100      NaN
# 3    2019-11-20 08:37:20.150    25.67
# 4    2019-11-20 08:37:20.200    25.67
# ...                      ...      ...
# 2596 2019-11-20 08:39:29.800      NaN
# 2597 2019-11-20 08:39:29.850      NaN
# 2598 2019-11-20 08:39:29.900      NaN
# 2599 2019-11-20 08:39:29.950      NaN
# 2600 2019-11-20 08:39:30.000      NaN
#
# [2601 rows x 2 columns]
# 2601

# %%
conn = pymysql.connect(
    host='192.168.100.120',
    port=16033,
    user='root',
    password='its@1234',
    db='UYeG_Cloud',
    charset='utf8'
)
curs = conn.cursor()

set_day1 = '2019-10-18 07:00:00'
set_day2 = '2019-10-18 23:39:30'


sql = "SELECT DataSavedTime, Item005 FROM HisItemCurr \
    WHERE DataSavedTime \
    BETWEEN '"+set_day1+"' and '"+set_day2+"
# 29 2019-10-18 16:23:48.900    84.30 2019-10-18 21:24:11 2019-10-18 21:24:31
# 30 2019-10-18 16:25:07.100    88.66 2019-10-18 21:24:11 2019-10-18 21:24:31
# 31 2019-10-18 16:25:07.200    88.66 2019-10-18 21:24:11 2019-10-18 21:24:31
# 32 2019-10-18 16:26:34.400    93.15 2019-10-18 21:24:11 2019-10-18 21:24:31
# 33 2019-10-18 16:26:34.500    93.15 2019-10-18 21:24:11 2019-10-18 21:24:31
# 34 2019-10-18 17:39:13.000    81.23 2019-10-18 21:24:11 2019-10-18 21:24:31
# 35 2019-10-18 17:39:13.100    81.23 2019-10-18 21:24:11 2019-10-18 21:24:31
# 36 2019-10-18 21:24:20.900    81.61 2019-10-18 21:24:11 2019-10-18 21:24:31
# 37 2019-10-18 21:24:21.000    81.61 2019-10-18 21:24:11 2019-10-18 21:24:31

# %%
sqls = []

for i in range(len(df['DataSavedTime'])):
    sql = "SELECT DataSavedTime, Item005 FROM HisItemCurr \
        WHERE DataSavedTime \
        BETWEEN '"+str(df['prev'][i])+"' and '"+str(df['post'][i])+"' ORDER BY DataSavedTime ASC"
    sqls.append(sql)

print(sqls)
# Out:
# ["SELECT DataSavedTime, Item005 FROM HisItemCurr         WHERE DataSavedTime         BETWEEN '2019-10-18 21:24:11' and '2019-10-18 21:24:31' ORDER BY DataSavedTime ASC", "SELECT DataSavedTime, Item005 FROM HisItemCurr         WHERE DataSavedTime         BETWEEN '2019-10-18 21:24:11' and '2019-10-18 21:24:31' ORDER BY DataSavedTime ASC", "SELECT DataSavedTime, Item005 FROM HisItemCurr         WHERE DataSavedTime         BETWEEN '2019-10-18 21:24:11' and '2019-10-18 21:24:31' ORDER BY DataSavedTime ASC", "SELECT DataSavedTime, Item005 FROM HisItemCurr         WHERE DataSavedTime         BETWEEN '2019-10-18 21:24:11' and '2019-10-18 21:24:31' ORDER BY DataSavedTime ASC", "SELECT DataSavedTime, Item005 FROM HisItemCurr         WHERE DataSavedTime         BETWEEN '2019-10-18 21:24:11' and '2019-10-18 21:24:31' ORDER BY DataSavedTime ASC", "SELECT DataSavedTime, Item005 FROM HisItemCurr         WHERE DataSavedTime         BETWEEN '2019-10-18 21:24:11' and '2019-10-18 21:24:31' ORDER BY DataSavedTime ASC", "SELECT DataSavedTime, Item005 FROM HisItemCurr         WHERE DataSavedTime         BETWEEN '2019-10-18 21:24:11' and '2019-10-18 21:24:31' ORDER BY DataSavedTime ASC", "SELECT DataSavedTime, Item005 FROM HisItemCurr         WHERE DataSavedTime         BETWEEN '2019-10-18 21:24:11' and '2019-10-18 21:24:31' ORDER BY DataSavedTime ASC", "SELECT DataSavedTime, Item005 FROM HisItemCurr         WHERE DataSavedTime         BETWEEN '2019-10-18 21:24:11' and '2019-10-18 21:24:31' ORDER BY DataSavedTime ASC", "SELECT DataSavedTime, Item005 FROM HisItemCurr         WHERE DataSavedTime         BETWEEN '2019-10-18 21:24:11' and '2019-10-18 21:24:31' ORDER BY DataSavedTime ASC", "SELECT DataSavedTime, Item005 FROM HisItemCurr         WHERE DataSavedTime         BETWEEN '2019-10-18 21:24:11' and '2019-10-18 21:24:31' ORDER BY DataSavedTime ASC", "SELECT DataSavedTime, Item005 FROM HisItemCurr         WHERE DataSavedTime         BETWEEN '2019-10-18 21:24:11' and '2019-10-18 21:24:31' ORDER BY DataSavedTime ASC", "SELECT DataSavedTime, Item005 FROM HisItemCurr         WHERE DataSavedTime         BETWEEN '2019-10-18 21:24:11' and '2019-10-18 21:24:31' ORDER BY DataSavedTime ASC", "SELECT DataSavedTime, Item005 FROM HisItemCurr         WHERE DataSavedTime         BETWEEN '2019-10-18 21:24:11' and '2019-10-18 21:24:31' ORDER BY DataSavedTime ASC", "SELECT DataSavedTime, Item005 FROM HisItemCurr         WHERE DataSavedTime         BETWEEN '2019-10-18 21:24:11' and '2019-10-18 21:24:31' ORDER BY DataSavedTime ASC", "SELECT DataSavedTime, Item005 FROM HisItemCurr         WHERE DataSavedTime         BETWEEN '2019-10-18 21:24:11' and '2019-10-18 21:24:31' ORDER BY DataSavedTime ASC", "SELECT DataSavedTime, Item005 FROM HisItemCurr         WHERE DataSavedTime         BETWEEN '2019-10-18 21:24:11' and '2019-10-18 21:24:31' ORDER BY DataSavedTime ASC", "SELECT DataSavedTime, Item005 FROM HisItemCurr         WHERE DataSavedTime         BETWEEN '2019-10-18 21:24:11' and '2019-10-18 21:24:31' ORDER BY DataSavedTime ASC", "SELECT DataSavedTime, Item005 FROM HisItemCurr         WHERE DataSavedTime         BETWEEN '2019-10-18 21:24:11' and '2019-10-18 21:24:31' ORDER BY DataSavedTime ASC", "SELECT DataSavedTime, Item005 FROM HisItemCurr         WHERE DataSavedTime         BETWEEN '2019-10-18 21:24:11' and '2019-10-18 21:24:31' ORDER BY DataSavedTime ASC", "SELECT DataSavedTime, Item005 FROM HisItemCurr         WHERE DataSavedTime         BETWEEN '2019-10-18 21:24:11' and '2019-10-18 21:24:31' ORDER BY DataSavedTime ASC", "SELECT DataSavedTime, Item005 FROM HisItemCurr         WHERE DataSavedTime         BETWEEN '2019-10-18 21:24:11' and '2019-10-18 21:24:31' ORDER BY DataSavedTime ASC", "SELECT DataSavedTime, Item005 FROM HisItemCurr         WHERE DataSavedTime         BETWEEN '2019-10-18 21:24:11' and '2019-10-18 21:24:31' ORDER BY DataSavedTime ASC", "SELECT DataSavedTime, Item005 FROM HisItemCurr         WHERE DataSavedTime         BETWEEN '2019-10-18 21:24:11 ...

# %%
conn = pymysql.connect(
    host='192.168.100.120',
    port=16033,
    user='root',
    password='its@1234',
    db='UYeG_Cloud',
    charset='utf8'
)
curs = conn.cursor()

for sql in sqls:
    curs.execute(sql)
    rows=curs.fetchall()

    data = list(rows)
    df = pd.DataFrame(data)

    df.columns = ['DataSavedTime', 'Item005']

#     print(df)
#     print(len(df))


    plt.figure(figsize=(15,5))
    plt.plot(df['DataSavedTime'], df['Item005'], label="Value")
    plt.legend(loc='best')
    plt.title("Current 0.1")
    plt.grid()
    plt.show()

conn.close()
# Out:
#               DataSavedTime  Item005
# 0   2019-10-18 21:24:11.000      NaN
# 1   2019-10-18 21:24:11.100      NaN
# 2   2019-10-18 21:24:11.200      NaN
# 3   2019-10-18 21:24:11.300      NaN
# 4   2019-10-18 21:24:11.400      NaN
# ..                      ...      ...
# 196 2019-10-18 21:24:30.600    32.85
# 197 2019-10-18 21:24:30.700    32.65
# 198 2019-10-18 21:24:30.800    32.65
# 199 2019-10-18 21:24:30.900    32.53
# 200 2019-10-18 21:24:31.000    32.73
#
# [201 rows x 2 columns]
# 201
# InterfaceErrorTraceback (most recent call last)
# <ipython-input-72-2be969b4b4f3> in <module>
#      10
#      11 for sql in sqls:
# ---> 12     curs.execute(sql)
#      13     rows=curs.fetchall()
#      14
#
# /usr/local/lib/python3.6/dist-packages/pymysql/cursors.py in execute(self, query, args)
#     168         query = self.mogrify(query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#     172         return result
#
# /usr/local/lib/python3.6/dist-packages/pymysql/cursors.py in _query(self, q)
#     326         self._last_executed = q
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#     330         return self.rowcount
#
# /usr/local/lib/python3.6/dist-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     514             else:
#     515                 sql = sql.encode(self.encoding, 'surrogateescape')
# --> 516         self._execute_command(COMMAND.COM_QUERY, sql)
#     517         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     518         return self._affected_rows
#
# /usr/local/lib/python3.6/dist-packages/pymysql/connections.py in _execute_command(self, command, sql)
#     748         """
#     749         if not self._sock:
# --> 750             raise err.InterfaceError("(0, '')")
#     751
#     752         # If the last query was unbuffered, make sure it finishes before
#
# InterfaceError: (0, '')
