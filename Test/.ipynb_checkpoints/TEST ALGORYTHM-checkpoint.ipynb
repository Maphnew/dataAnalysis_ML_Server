# %%
import pandas as pd
import pymysql
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
conn = pymysql.connect(
    host='192.168.100.225',
    port=3306,
    user='root',
    password='its@1234',
    db='TEST_KUMHO',
    charset='utf8'
)

curs = conn.cursor()

sql = "select DataSavedTime, Item001 from HisItemVolt WHERE DataSavedTime between \
    '2019-11-08 15:50:00' and '2019-11-08 16:00:59' ORDER BY DataSavedTime ASC"
curs.execute(sql)

rows=curs.fetchall()
# print(rows)
li = list(rows)
conn.close()
df = pd.DataFrame(li)
df.columns = ['DataSavedTime', 'Item001']
print(df)
# Out:
#               DataSavedTime  Item001
# 0   2019-11-08 15:50:31.100    380.0
# 1   2019-11-08 15:50:31.200    380.0
# 2   2019-11-08 15:50:31.300    380.0
# 3   2019-11-08 15:50:31.400    380.0
# 4   2019-11-08 15:50:31.500    380.0
# ..                      ...      ...
# 671 2019-11-08 16:00:41.100    380.0
# 672 2019-11-08 16:00:41.200    380.0
# 673 2019-11-08 16:00:41.300    380.0
# 674 2019-11-08 16:00:41.400    380.0
# 675 2019-11-08 16:00:41.500    380.0
#
# [676 rows x 2 columns]

# %%
plt.figure(figsize=(15,10))
plt.plot(df['DataSavedTime'], df['Item001'], label="Item001")
# plt.ylim([350, 390])
plt.legend(loc='best')
plt.title("TITLE")
plt.grid()
plt.show()
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-15-0904b08e9ab6> in <module>
#       1 plt.figure(figsize=(15,10))
#       2 plt.plot(df['DataSavedTime'], df['Item001'], label="Item001")
# ----> 3 plt.ylim([350, 390])
#       4 plt.legend(loc='best')
#       5 plt.title("TITLE")
#
# TypeError: 'tuple' object is not callable
